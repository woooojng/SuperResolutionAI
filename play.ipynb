# %%
from scipy.io import loadmat
# load the mat file
path = r"C:\Users\CMME260629\projects_cmme\SuperResolutionAI\super_resolution\python_simulation_results\benign_10\simulation_low.mat"
# Load the entire .mat file into a dictionary
data = loadmat(path)
print(data.keys())
# Access a specific variable by its MATLAB name
# matrix_data = data['variable_name']

# print(matrix_data)
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'scan_lines', 'sound_speed_map', 'density_map', 'kgrid_dt', 'kgrid_Nt', 'element_width', 'sample_name'])

# %%
sos_map[:,:,0].astype(int)
# Out:
# array([[1529, 1530, 1515, ..., 1565, 1549, 1490],
#        [1515, 1515, 1529, ..., 1514, 1524, 1540],
#        [1514, 1530, 1528, ..., 1530, 1515, 1529],
#        ...,
#        [1530, 1515, 1515, ..., 1525, 1535, 1502],
#        [1529, 1514, 1514, ..., 1515, 1515, 1515],
#        [1529, 1514, 1514, ..., 1515, 1529, 1530]], shape=(51, 203))

# %%
sos_map = data['density_map']
import matplotlib.pyplot as plt

plt.imshow(sos_map[:, :, 0], cmap="jet")
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 sos_map = data['density_map']
#       2 import matplotlib.pyplot as plt
# ----> 4 plt.figure(int(sos_map[:,:,0].astype(int)),cmap = "jet")
#       5 plt.colorbar()
#       6 plt.show()
#
# TypeError: only length-1 arrays can be converted to Python scalars
